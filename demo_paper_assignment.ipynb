# %% [markdown]
# # 🎓 Conference Paper Assignment with AI
#
# ## The Challenge
#
# You're organizing an AI conference with **15 accepted papers** and **6 sessions** (oral and poster).
#
# **The complexity:**
# - 📊 Oral sessions require scores ≥ 4.0
# - 🏷️ Papers must match session topics
# - 👥 Authors can't present twice in same session
# - 📦 Capacity limits per session
# - ✅ All papers must be assigned
#
# **The solution?** AI-powered constraint solving!

# %% [markdown]
# ## Step 1: Define the Problem
#
# Describe the scheduling problem in plain English:

# %%
problem_description = '''
Accepted papers

There are fifteen accepted papers. For each paper, we know the short ID, the subject area, the reviewer score (on a five-point scale), and the numeric ID of the presenting author.

P1 has area Computer Vision (CV), score 4.7, and author A1
P2 has area CV, score 4.5, author A2
P3 has area CV, score 4.2, author A3
P4 has area Natural-Language Processing (NLP), score 4.8, author A4
P5 has area NLP, score 4.1, author A1 (same author as P1)
P6 has area Systems (Sys), score 4.3, author A5
P7 has area Reinforcement Learning (RL), score 4.0, author A6
P8 has area Theory, score 3.8, author A7
P9 has area Theory, score 4.4, author A8
P10 has area Sys, score 3.9, author A3 (same author as P3)
P11 has area RL, score 3.7, author A9
P12 has area Sys, score 4.0, author A10
P13 has area NLP, score 3.9, author A11
P14 has area Theory, score 4.6, author A12
P15 has area CV, score 3.9, author A2 (same author as P2)

Conference sessions

The committee has defined six sessions. Each session has three properties: a format (either oral or poster), a capacity (the maximum number of papers it can host), and a topic whitelist (the list of subject areas permitted in that session).

Session OM-A is an oral session with a capacity of 2 papers. It allows only papers in CV.
Session OM-B is an oral session with a capacity of 2 papers. It allows only papers in RL.
Session OA-A is an oral session with a capacity of 2 papers. It allows only papers in NLP.
Session OA-B is an oral session with a capacity of 2 papers. It allows papers in Systems and Theory.
Session Poster-1 is a poster session with a capacity of 4 papers. It allows papers in CV, Systems, and RL.
Session Poster-2 is a poster session with a capacity of 4 papers. It allows papers in NLP and Theory.

Rules that every valid schedule must satisfy

Oral-talk eligibility rule: A paper may be placed in an oral session only if its reviewer score is at least 4.0.

Topic-match rule: A paper can only be assigned to a session if its subject area appears in the session’s topic whitelist.

Capacity rule: A session cannot be assigned more papers than its capacity allows.

Author-session rule: No author may present more than one paper in the same session.
For example, if author A1 is scheduled to present paper P1 in session OM-A, then their other paper P5 must be placed in a different session, such as OA-A or Poster-2, but not also in OM-A.

Coverage requirement: All fifteen papers must be assigned, each to exactly one session. Every assignment must satisfy all of the rules above.
'''

print("✓ Problem defined")
# Out:
# ✓ Problem defined

# %% [markdown]
# ## Step 2: Let CARNAP Solve It
#
# The framework should automatically:
# - Identify this as a Constraint Satisfaction Problem (CSP)
# - Translate the problem into MiniZinc code
# - Find a valid assignment by running the code
#
# Let's first load the config file and initialize an LLM

# %%
import yaml
from agents.generation.api import AzureOpenAIGenerator
from agents.meta_agents.planner import Planner, TracePersister

# Load config and initialize
with open('config.yaml', 'r') as file:
    config = yaml.safe_load(file)

azure_config = config['api_config']['gpt-4o-azure']
llm = AzureOpenAIGenerator(
    model_name=azure_config['model_name'],
    api_key=azure_config['api_key'],
    model_version=azure_config['openai_api_version'],
    azure_endpoint=azure_config['azure_endpoint']
)
# Out:
# 2025-11-06 09:49:13,448 | INFO | NumExpr defaulting to 16 threads.

# %% [markdown]
# We now pass our problem to a planner:
# - that recognizes the problem type
# - and devises a plan

# %%
router = Planner(generator=llm)
plan, memory, problem_ids = router({"problem": problem_description})
# Out:
# 2025-11-06 09:49:20,476 | INFO | Registered agent '<PLAN_START>'
# 2025-11-06 09:49:20,477 | INFO | Registered agent '<PLAN_END>'
# 2025-11-06 09:49:20,478 | INFO | Registered agent 'lp_solver'
# 2025-11-06 09:49:20,478 | INFO | Registered agent 'fol_solver'
# 2025-11-06 09:49:20,479 | INFO | Registered agent 'csp_solver'
# 2025-11-06 09:49:20,479 | INFO | Registered agent 'smt_solver'
# 2025-11-06 09:49:20,480 | INFO | Registered agent 'ilp_solver'
# 2025-11-06 09:49:20,480 | INFO | Registered agent 'epistemic_solver'
# 2025-11-06 09:49:20,480 | INFO | Registered agent 'risk_solver'
# 2025-11-06 09:49:20,481 | INFO | Registered agent 'compositional_solver'
# 2025-11-06 09:49:20,481 | INFO | Registered agent 'causal_solver'
# /remote/idiap.svm/home.active/pbeckmann/projects/adaptive_symbolic_reasoning/agents/generation/api.py:203: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   return self.client(messages)
# 2025-11-06 09:49:22,072 | INFO | HTTP Request: POST https://lunarchatgpt.openai.azure.com/openai/deployments/lunar-chatgpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# 2025-11-06 09:49:22,086 | INFO | Scratchpad WRITE problem_type_ques_1=CSP (ttl=None)
# 2025-11-06 09:49:22,086 | INFO | Scratchpad WRITE context_ques_1=There are fifteen accepted papers with different subject are (ttl=None)
# 2025-11-06 09:49:22,087 | INFO | Scratchpad WRITE question_ques_1=Assign all fifteen papers to the defined conference sessions (ttl=None)
# 2025-11-06 09:49:22,088 | INFO | Scratchpad WRITE options_ques_1= (ttl=None)
# 2025-11-06 09:49:22,088 | INFO | Scratchpad WRITE csp_input_ques_1={'problem': '\nAccepted papers\n\nThere are fifteen accepted (ttl=None)
# 2025-11-06 09:49:22,088 | INFO | Scratchpad WRITE description_ques_1=For a Constraint Satisfaction Problem (CSP), find a variable (ttl=None)
# 2025-11-06 09:49:22,089 | INFO | Scratchpad WRITE GOAL=Solve the constraint satisfaction problem to correctly assig (ttl=None)
# 2025-11-06 09:49:22,089 | INFO | Scratchpad WRITE parsing_result=[{'problem_id': 'ques_1', 'problem_type': 'CSP', 'context':  (ttl=None)
# 2025-11-06 09:49:22,089 | INFO | Scratchpad WRITE portfolio={'<PLAN_START>': {'goal': 'Special control marker, indicatin (ttl=None)
# 2025-11-06 09:49:22,819 | INFO | HTTP Request: POST https://lunarchatgpt.openai.azure.com/openai/deployments/lunar-chatgpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# 2025-11-06 09:49:22,821 | INFO | [planner] produced plan spec: {'agents': ['ques_1', 'csp_solver', '<PLAN_END>'], 'edges': [['ques_1', 'csp_solver'], ['csp_solver', '<PLAN_END>']]}

# %% [markdown]
# Finally, we execute the plan.
#
# The LLM is called to formalize the problem into some formal code. The code is then passed to dedicated solver.

# %%
plan[0].execute(memory, TracePersister())

result = memory.read(f"result_{problem_ids[0]}")
print(result["assignments"])
# Out:
# 2025-11-06 10:05:36,321 | INFO | Execute plan with topological order...
# 2025-11-06 10:05:36,322 | INFO | Trace saved: <PLAN_START> → None
# 2025-11-06 10:05:36,322 | INFO | Trace saved: ques_1 → None
# 2025-11-06 10:05:36,323 | INFO | ================================================================================
# 2025-11-06 10:05:36,323 | INFO | PROBLEM TEXT SENT TO FORMALIZATION:
# 2025-11-06 10:05:36,324 | INFO | ================================================================================
# 2025-11-06 10:05:36,325 | INFO |
#
# Accepted papers
#
# There are fifteen accepted papers. For each paper, we know the short ID, the subject area, the reviewer score (on a five-point scale), and the numeric ID of the presenting author.
#
# P1 has area Computer Vision (CV), score 4.7, and author A1
# P2 has area CV, score 4.5, author A2
# P3 has area CV, score 4.2, author A3
# P4 has area Natural-Language Processing (NLP), score 4.8, author A4
# P5 has area NLP, score 4.1, author A1 (same author as P1)
# P6 has area Systems (Sys), score 4.3, author A5
# P7 has area Reinforcement Learning (RL), score 4.0, author A6
# P8 has area Theory, score 3.8, author A7
# P9 has area Theory, score 4.4, author A8
# P10 has area Sys, score 3.9, author A3 (same author as P3)
# P11 has area RL, score 3.7, author A9
# P12 has area Sys, score 4.0, author A10
# P13 has area NLP, score 3.9, author A11
# P14 has area Theory, score 4.6, author A12
# P15 has area CV, score 3.9, author A2 (same author as P2)
#
# Conference sessions
#
# The committee has defined six sessions. Each session has three properties: a format (either oral or poster), a capacity (the maximum number of papers it can host), and a topic whitelist (the list of subject areas permitted in that session).
#
# Session OM-A is an oral session with a capacity of 2 papers. It allows only papers in CV.
# Session OM-B is an oral session with a capacity of 2 papers. It allows only papers in RL.
# Session OA-A is an oral session with a capacity of 2 papers. It allows only papers in NLP.
# Session OA-B is an oral session with a capacity of 2 papers. It allows papers in Systems and Theory.
# Session Poster-1 is a poster session with a capacity of 4 papers. It allows papers in CV, Systems, and RL.
# Session Poster-2 is a poster session with a capacity of 4 papers. It allows papers in NLP and Theory.
#
# Rules that every valid schedule must satisfy
#
# Oral-talk eligibility rule: A paper may be placed in an oral session only if its reviewer score is at least 4.0.
#
# Topic-match rule: A paper can only be assigned to a session if its subject area appears in the session’s topic whitelist.
#
# Capacity rule: A session cannot be assigned more papers than its capacity allows.
#
# Author-session rule: No author may present more than one paper in the same session.
# For example, if author A1 is scheduled to present paper P1 in session OM-A, then their other paper P5 must be placed in a different session, such as OA-A or Poster-2, but not also in OM-A.
#
# Coverage requirement: All fifteen papers must be assigned, each to exactly one session. Every assignment must satisfy all of the rules above.
#
# 2025-11-06 10:05:36,325 | INFO | ================================================================================
# 2025-11-06 10:05:42,283 | INFO | HTTP Request: POST https://lunarchatgpt.openai.azure.com/openai/deployments/lunar-chatgpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# 2025-11-06 10:05:42,285 | INFO | Scratchpad WRITE minizinc_code_csp_solver=include "globals.mzn";
#
# /* ENUMERATIONS */
# enum PAPER = {P1, (ttl=None)
# 2025-11-06 10:05:42,285 | INFO | ================================================================================
# 2025-11-06 10:05:42,286 | INFO | GENERATED MINIZINC CODE:
# 2025-11-06 10:05:42,287 | INFO | ================================================================================
# 2025-11-06 10:05:42,287 | INFO |
# include "globals.mzn";
#
# /* ENUMERATIONS */
# enum PAPER = {P1, P2, P3, P4, P5, P6, P7, P8, P9, P10, P11, P12, P13, P14, P15};
# enum AREA = {CV, NLP, Sys, RL, Theory};
# enum AUTHOR = {A1, A2, A3, A4, A5, A6, A7, A8, A9, A10, A11, A12};
# enum SESSION = {OM_A, OM_B, OA_A, OA_B, Poster_1, Poster_2};
#
# /* PAPER ATTRIBUTES */
# array[PAPER] of AREA: paper_area = [CV, CV, CV, NLP, NLP, Sys, RL, Theory, Theory, Sys, RL, Sys, NLP, Theory, CV];
# array[PAPER] of float: paper_score = [4.7, 4.5, 4.2, 4.8, 4.1, 4.3, 4.0, 3.8, 4.4, 3.9, 3.7, 4.0, 3.9, 4.6, 3.9];
# array[PAPER] of AUTHOR: paper_author = [A1, A2, A3, A4, A1, A5, A6, A7, A8, A3, A9, A10, A11, A12, A2];
#
# /* SESSION PROPERTIES */
# array[SESSION] of int: session_capacity = [2, 2, 2, 2, 4, 4];
# array[SESSION] of set of AREA: session_topics = [{CV}, {RL}, {NLP}, {Sys, Theory}, {CV, Sys, RL}, {NLP, Theory}];
#
# /* DECISION VARIABLES */
# array[PAPER] of var SESSION: paper_session;
#
# /* CONSTRAINTS */
#
# % Coverage requirement: All papers must be assigned to exactly one session
# constraint forall(p in PAPER) (
#   paper_session[p] in SESSION
# );
#
# % Oral-talk eligibility rule: Papers in oral sessions must have a score of at least 4.0
# constraint forall(p in PAPER) (
#   paper_session[p] in {OM_A, OM_B, OA_A, OA_B} -> paper_score[p] >= 4.0
# );
#
# % Topic-match rule: Papers can only be assigned to sessions allowing their area
# constraint forall(p in PAPER) (
#   paper_session[p] in {s | s in SESSION where paper_area[p] in session_topics[s]}
# );
#
# % Capacity rule: Sessions cannot exceed their capacity
# constraint forall(s in SESSION) (
#   sum([paper_session[p] == s | p in PAPER]) <= session_capacity[s]
# );
#
# % Author-session rule: No author can present more than one paper in the same session
# constraint forall(s in SESSION, a in AUTHOR) (
#   sum([paper_author[p] == a /\ paper_session[p] == s | p in PAPER]) <= 1
# );
#
# solve satisfy;
# 2025-11-06 10:05:42,287 | INFO | ================================================================================
# 2025-11-06 10:05:42,288 | INFO | Attempt 1/1
# 2025-11-06 10:05:42,288 | INFO | Running command: minizinc --solver gecode /tmp/tmph5ho1d1n.mzn
# 2025-11-06 10:05:42,720 | INFO | MiniZinc stdout:
# paper_session = [P1: Poster_1, P2: OM_A, P3: OM_A, P4: OA_A, P5: OA_A, P6: OA_B, P7: OM_B, P8: Poster_2, P9: Poster_2, P10: Poster_1, P11: Poster_1, P12: OA_B, P13: Poster_2, P14: Poster_2, P15: Poster_1];
# ----------
#
# 2025-11-06 10:05:42,721 | INFO | Parsed 1 solutions
# 2025-11-06 10:05:42,721 | INFO | Scratchpad WRITE solutions_csp_solver=[{'assignments': {'paper_session': {'P1': 'Poster_1', 'P2':  (ttl=None)
# 2025-11-06 10:05:42,721 | INFO | MiniZinc ran successfully. Found 1 solutions
# 2025-11-06 10:05:42,722 | INFO | Scratchpad WRITE result_ques_1={'solutions': [{'assignments': {'paper_session': {'P1': 'Pos (ttl=None)
# 2025-11-06 10:05:42,722 | INFO | Trace saved: csp_solver → {'solutions': [{'assignments': {'paper_session': {'P1': 'Poster_1', 'P2': 'OM_A', 'P3': 'OM_A', 'P4': 'OA_A', 'P5': 'OA_A', 'P6': 'OA_B', 'P7': 'OM_B', 'P8': 'Poster_2', 'P9': 'Poster_2', 'P10': 'Poster_1', 'P11': 'Poster_1', 'P12': 'OA_B', 'P13': 'Poster_2', 'P14': 'Poster_2', 'P15': 'Poster_1'}}}], 'assignments': {'paper_session': {'P1': 'Poster_1', 'P2': 'OM_A', 'P3': 'OM_A', 'P4': 'OA_A', 'P5': 'OA_A', 'P6': 'OA_B', 'P7': 'OM_B', 'P8': 'Poster_2', 'P9': 'Poster_2', 'P10': 'Poster_1', 'P11': 'Poster_1', 'P12': 'OA_B', 'P13': 'Poster_2', 'P14': 'Poster_2', 'P15': 'Poster_1'}}, 'minizinc_code': 'include "globals.mzn";\n\n/* ENUMERATIONS */\nenum PAPER = {P1, P2, P3, P4, P5, P6, P7, P8, P9, P10, P11, P12, P13, P14, P15};\nenum AREA = {CV, NLP, Sys, RL, Theory};\nenum AUTHOR = {A1, A2, A3, A4, A5, A6, A7, A8, A9, A10, A11, A12};\nenum SESSION = {OM_A, OM_B, OA_A, OA_B, Poster_1, Poster_2};\n\n/* PAPER ATTRIBUTES */\narray[PAPER] of AREA: paper_area = [CV, CV, CV, NLP, NLP, Sys, RL, Theory, Theory, Sys, RL, Sys, NLP, Theory, CV];\narray[PAPER] of float: paper_score = [4.7, 4.5, 4.2, 4.8, 4.1, 4.3, 4.0, 3.8, 4.4, 3.9, 3.7, 4.0, 3.9, 4.6, 3.9];\narray[PAPER] of AUTHOR: paper_author = [A1, A2, A3, A4, A1, A5, A6, A7, A8, A3, A9, A10, A11, A12, A2];\n\n/* SESSION PROPERTIES */\narray[SESSION] of int: session_capacity = [2, 2, 2, 2, 4, 4];\narray[SESSION] of set of AREA: session_topics = [{CV}, {RL}, {NLP}, {Sys, Theory}, {CV, Sys, RL}, {NLP, Theory}];\n\n/* DECISION VARIABLES */\narray[PAPER] of var SESSION: paper_session;\n\n/* CONSTRAINTS */\n\n% Coverage requirement: All papers must be assigned to exactly one session\nconstraint forall(p in PAPER) (\n  paper_session[p] in SESSION\n);\n\n% Oral-talk eligibility rule: Papers in oral sessions must have a score of at least 4.0\nconstraint forall(p in PAPER) (\n  paper_session[p] in {OM_A, OM_B, OA_A, OA_B} -> paper_score[p] >= 4.0\n);\n\n% Topic-match rule: Papers can only be assigned to sessions allowing their area\nconstraint forall(p in PAPER) (\n  paper_session[p] in {s | s in SESSION where paper_area[p] in session_topics[s]}\n);\n\n% Capacity rule: Sessions cannot exceed their capacity\nconstraint forall(s in SESSION) (\n  sum([paper_session[p] == s | p in PAPER]) <= session_capacity[s]\n);\n\n% Author-session rule: No author can present more than one paper in the same session\nconstraint forall(s in SESSION, a in AUTHOR) (\n  sum([paper_author[p] == a /\\ paper_session[p] == s | p in PAPER]) <= 1\n);\n\nsolve satisfy;'}
# 2025-11-06 10:05:42,723 | INFO | Trace saved: <PLAN_END> → None
# 2025-11-06 10:05:42,723 | INFO | Topological execution complete
# {'paper_session': {'P1': 'Poster_1', 'P2': 'OM_A', 'P3': 'OM_A', 'P4': 'OA_A', 'P5': 'OA_A', 'P6': 'OA_B', 'P7': 'OM_B', 'P8': 'Poster_2', 'P9': 'Poster_2', 'P10': 'Poster_1', 'P11': 'Poster_1', 'P12': 'OA_B', 'P13': 'Poster_2', 'P14': 'Poster_2', 'P15': 'Poster_1'}}

# %% [markdown]
# ## Step 3: Inspect Generated Constraints
#
# As the organizer, **verify all rules were correctly captured** in formal constraints:

# %%
print(result['minizinc_code'])
# Out:
# include "globals.mzn";
#
# /* ENUMERATIONS */
# % Papers and Authors
# enum PAPER = {P1, P2, P3, P4, P5, P6, P7, P8, P9, P10, P11, P12, P13, P14, P15};
# enum AUTHOR = {A1, A2, A3, A4, A5, A6, A7, A8, A9, A10, A11, A12};
# enum AREA = {CV, NLP, Sys, RL, Theory};
# enum SESSION = {OM_A, OM_B, OA_A, OA_B, Poster_1, Poster_2};
#
# /* PAPER PROPERTIES */
# array[PAPER] of AREA: paper_area = [CV, CV, CV, NLP, NLP, Sys, RL, Theory, Theory, Sys, RL, Sys, NLP, Theory, CV];
# array[PAPER] of float: paper_score = [4.7, 4.5, 4.2, 4.8, 4.1, 4.3, 4.0, 3.8, 4.4, 3.9, 3.7, 4.0, 3.9, 4.6, 3.9];
# array[PAPER] of AUTHOR: paper_author = [A1, A2, A3, A4, A1, A5, A6, A7, A8, A3, A9, A10, A11, A12, A2];
#
# /* SESSION PROPERTIES */
# array[SESSION] of set of AREA: session_whitelist = [
#   {CV},    % OM-A
#   {RL},    % OM-B
#   {NLP},   % OA-A
#   {Sys, Theory}, % OA-B
#   {CV, Sys, RL}, % Poster-1
#   {NLP, Theory}  % Poster-2
# ];
# array[SESSION] of int: session_capacity = [2, 2, 2, 2, 4, 4];
# array[SESSION] of bool: session_is_oral = [true, true, true, true, false, false];
#
# /* DECISION VARIABLES */
# array[PAPER] of var SESSION: paper_session;
#
# /* CONSTRAINTS */
# /* Oral-talk eligibility rule */
# constraint forall(p in PAPER) (
#   paper_session[p] in {OM_A, OM_B, OA_A, OA_B} -> paper_score[p] >= 4.0
# );
#
# /* Topic-match rule */
# constraint forall(p in PAPER) (
#   paper_area[p] in session_whitelist[paper_session[p]]
# );
#
# /* Capacity rule */
# constraint forall(s in SESSION) (
#   sum([paper_session[p] == s | p in PAPER]) <= session_capacity[s]
# );
#
# /* Author-session rule */
# constraint forall(a in AUTHOR, s in SESSION) (
#   sum([paper_session[p] == s /\ paper_author[p] == a | p in PAPER]) <= 1
# );
#
# /* Coverage requirement */
# constraint forall(p in PAPER) (
#   paper_session[p] in SESSION
# );
#
# solve satisfy;
